# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Census Cartographic Boundary Files, 2018 vintage
# `census.gov-boundaries-2020-1.1.1` Last Update: 2022-01-12T18:51:18
#
# _The cartographic boundary files are simplified representations of selected geographic areas from the Census Bureau’s MAF/TIGER geographic database. These boundary files are specifically designed for small scale thematic mapping._
#
#
# This data package collects a selection of the US Census cartographic shape
# files, which are designed to be used in creating maps. For each type of region,
# they come in a varity of resolutions, so they are more suitable for creating
# web maps than the much larger TIGER files.
#
# <center><img src="http://library.metatab.org/census.gov-boundaries-2018-1.2.4/notebooks/continental.png" width='600'/></center>
#
# These files have been processed to all have the same schema and use ACS style
# Geoids. The original files have AFF style geoids, which have extra '00'
# characters in them.
#
# The use of a single schema means that in some files, some columns are
# consistently empty. For instance, ZCTA ( which are similar to ZIP code regions)
# may not be entirely within a single state or county, so they don't have a
# well-defined state and county. In these cases, the ``state_fips`` ``stusab``
# and ``county_fips`` columns will be empty.
# ## Documentation Links
#
# * [Homepage](https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html) Page with links to all of the files
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [state_500k](python:pylib#process_geo)**. State boundaries,  scale  500K:1
# * ** [state_5m](python:pylib#process_geo)**. State boundaries,  scale 5M:1
# * ** [state_20m](python:pylib#process_geo)**. State boundaries,  scale 20M:1
# * ** [county_500k](python:pylib#process_geo)**. County boundaries,  scale 500K:1
# * ** [county_5m](python:pylib#process_geo)**. County boundaries,  scale 5M:1
# * ** [county_20m](python:pylib#process_geo)**. County boundaries,  scale 20M:1
# * ** [nation_5m](python:pylib#process_geo)**. National boundary, 5M:1
# * ** [nation_20m](python:pylib#process_geo)**. National boundary 20M:1
# * ** [zcta_500k](python:pylib#process_geo)**. ZCTA (Zip Codes), scale 500K:1
#
# ## References
# <ul><li> <strong>state_500k_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_state_500k.zip</em>. State boundaries,  scale  500K:1</li><li> <strong>state_5m_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_state_5m.zip</em>. State boundaries,  scale 5M:1</li><li> <strong>state_20m_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_state_20m.zip</em>. State boundaries,  scale 20M:1</li><li> <strong>county_500k_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_county_500k.zip</em>. County boundaries,  scale 500K:1</li><li> <strong>county_5m_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_county_5m.zip</em>. County boundaries,  scale 5M:1</li><li> <strong>county_20m_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_county_20m.zip</em>. County boundaries,  scale 20M:1</li><li> <strong>nation_5m_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_nation_5m.zip</em>. National boundary, 5M:1</li><li> <strong>nation_20m_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_nation_20m.zip</em>. National boundary 20M:1</li><li> <strong>zcta_500k_source</string>, <em>shape+https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_us_zcta510_500k.zip</em>. ZCTA (Zip Codes), scale 500K:1</li><ul>

# %%
src = pkg.reference('state_500k_source').geoframe()
src.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS          NAME LSAD  \
# 0      66  01802705  0400000US66    66     GU          Guam   00
# 1      48  01779801  0400000US48    48     TX         Texas   00
# 2      55  01779806  0400000US55    55     WI     Wisconsin   00
# 3      44  01219835  0400000US44    44     RI  Rhode Island   00
# 4      36  01779796  0400000US36    36     NY      New York   00
#
#           ALAND       AWATER  \
# 0     543555847    934337453
# 1  676680588914  18979352230
# 2  140292246684  29343721650
# 3    2677759219   1323691129
# 4  122049520861  19256750161
#
#                                             geometry
# 0  MULTIPOLYGON (((144.64538 13.23627, 144.64716 ...
# 1  MULTIPOLYGON (((-94.71830 29.72885, -94.71721 ...
# 2  MULTIPOLYGON (((-86.95617 45.35549, -86.95463 ...
# 3  MULTIPOLYGON (((-71.28802 41.64558, -71.28647 ...
# 4  MULTIPOLYGON (((-72.03683 41.24984, -72.03496 ...

# %%
df = pkg.resource('state_500k').geoframe()
df.head()
# Out:
#        geoid          name stusab  state_fips county_fips     land_area  \
# 0  04000US66          Guam   None          66        None     543555847
# 1  04000US48         Texas     TX          48        None  676680588914
# 2  04000US55     Wisconsin     WI          55        None  140292246684
# 3  04000US44  Rhode Island     RI          44        None    2677759219
# 4  04000US36      New York     NY          36        None  122049520861
#
#     water_area                                           geometry
# 0    934337453  MULTIPOLYGON (((144.64538 13.23627, 144.64716 ...
# 1  18979352230  MULTIPOLYGON (((-94.71830 29.72885, -94.71721 ...
# 2  29343721650  MULTIPOLYGON (((-86.95617 45.35549, -86.95463 ...
# 3   1323691129  MULTIPOLYGON (((-71.28802 41.64558, -71.28647 ...
# 4  19256750161  MULTIPOLYGON (((-72.03683 41.24984, -72.03496 ...

# %%
df[df.geometry.isnull()]
# Out:
# Empty GeoDataFrame
# Columns: [geoid, name, stusab, state_fips, county_fips, land_area, water_area, geometry]
# Index: []

# %%
df.plot()

# %%
strs = [str(g) for g in df.geometry]
